# %% [markdown]
# # Stack Plot Example Using Random Numbers

# %%
# import packages
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Create some random data to plot

# %%
x = range(1,21)
y1 = np.random.rand(20)
y2 = np.random.rand(20)

# print values to see what we have
print(x)
print(y1)
print(y2)
# Out:
# range(1, 21)
# [0.73158935 0.49188951 0.49348843 0.16039614 0.57269417 0.94097148
#  0.97731836 0.1270635  0.21518277 0.50723005 0.77970714 0.17868719
#  0.20362606 0.70728062 0.40875477 0.78633587 0.33620766 0.04659268
#  0.50512357 0.28175042]
# [0.47691229 0.71142794 0.62560295 0.96277048 0.06936444 0.80432476
#  0.60914189 0.02329123 0.18362577 0.74718032 0.797809   0.07853815
#  0.40574356 0.2267198  0.82570185 0.1649269  0.22298652 0.64417771
#  0.52325048 0.19253512]

# %%
# setup legend for plot
plt.plot([], [], color='r', label = 'y1')
plt.plot([], [], color='b', label = 'y2')

# setup the plot
plt.stackplot(x, y1, y2, colors= ['r', 'b'])
plt.title('Stack Plot Random Numbers')
plt.legend()
plt.show()
